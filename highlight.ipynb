# %%
pip install nltk librosa pandas
# Out:
# Requirement already satisfied: nltk in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (3.9.1)
# Requirement already satisfied: librosa in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (0.11.0)
# Requirement already satisfied: pandas in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (2.3.2)
# Requirement already satisfied: click in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (0.61.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (1.16.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (1.7.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (1.1.1)
# Requirement already satisfied: standard-aifc in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (3.13.0)
# Requirement already satisfied: standard-sunau in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from librosa) (3.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: packaging in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from pooch>=1.1->librosa) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.8.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: colorama in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: standard-chunk in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from standard-aifc->librosa) (3.13.0)
# Requirement already satisfied: audioop-lts in c:\users\vinbo\anaconda3\envs\sports-env\lib\site-packages (from standard-aifc->librosa) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\vinbo\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import pandas as pd

segments = []
with open("commentary_segments.txt", "r", encoding="utf-8") as f:
    for line in f:
        if line.strip():
            # Example format: [start -> end] segment_text
            parts = line.split("] ")
            time_range = parts[0][1:]  # remove starting '['
            start, end = time_range.replace("s","").split(" -> ")
            text = parts[1]
            segments.append({"start": float(start), "end": float(end), "text": text})

df = pd.DataFrame(segments)

# %%
df.head(5)
# Out:
#    start    end                                               text
# 0   0.00   6.28   How do the Norwich players feel at this point...
# 1   6.28  10.72   Absolutely loving it because the fans will be...
# 2  10.72  15.08   They all want first touches, give it to a yel...
# 3  15.08  18.16   Jamal Lewis up against Bernardo Silva looks...\n
# 4  18.16  19.88        Wow, that looks a problem, that one does.\n

# %%
import librosa
import numpy as np

audio_file = "commentary.wav"
y, sr = librosa.load(audio_file, sr=None)

# Short-time energy (simple excitement metric)
frame_length = 2048
hop_length = 512
energy = np.array([sum(abs(y[i:i+frame_length]**2)) for i in range(0, len(y), hop_length)])

# Normalize to 0–1
energy = (energy - energy.min()) / (energy.max() - energy.min())

# Map segment start/end to energy
def get_segment_energy(start, end):
    start_frame = int(start * sr / hop_length)
    end_frame = int(end * sr / hop_length)
    return energy[start_frame:end_frame].mean()

df["audio_score"] = df.apply(lambda row: get_segment_energy(row["start"], row["end"]), axis=1)

# %%
df.sort_values(by='audio_score', ascending=False).head(5)
# Out:
#         start      end                                               text  \
# 1675  5883.16  5885.16                            Norwich have done it!\n
# 363   1683.00  1691.56   It's 2-0! Norwich City have had two chances i...
# 1676  5885.16  5887.16            That is a wonderful Carrow Road night\n
# 248   1083.00  1091.32   side delivers, McLean's head on, and he's in,...
# 1674  5881.16  5883.16               Norwich putting him under pressure\n
#
#       audio_score
# 1675     0.496202
# 363      0.469073
# 1676     0.423164
# 248      0.418614
# 1674     0.377807

# %%
df["vader_score"] = df["text"].apply(lambda x: analyser.polarity_scores(x)["compound"])

# %%
df.sort_values(by='audio_score', ascending=False).head(5)
# Out:
#         start      end                                               text  \
# 1675  5883.16  5885.16                            Norwich have done it!\n
# 363   1683.00  1691.56   It's 2-0! Norwich City have had two chances i...
# 1676  5885.16  5887.16            That is a wonderful Carrow Road night\n
# 248   1083.00  1091.32   side delivers, McLean's head on, and he's in,...
# 1674  5881.16  5883.16               Norwich putting him under pressure\n
#
#       audio_score  vader_score
# 1675     0.496202       0.0000
# 363      0.469073       0.2714
# 1676     0.423164       0.5719
# 248      0.418614       0.5267
# 1674     0.377807      -0.2960

# %%
alpha = 0.5  # weight for sentiment
beta = 0.5   # weight for audio

df["final_score"] = alpha * (df["vader_score"] * 10) + beta * (df["audio_score"] * 10)

# %%
df.sort_values(by='final_score', ascending=False).head(5)
# Out:
#         start      end                                               text  \
# 257   1137.00  1142.84   and they get them in that box from that corne...
# 698   3311.96  3319.00   how good are these set-up backs keep raving a...
# 252   1109.88  1116.28   What a goal, great delivery from the corner, ...
# 367   1711.80  1717.00   that's brilliant from Norwich City, what a gr...
# 1676  5885.16  5887.16            That is a wonderful Carrow Road night\n
#
#       audio_score  vader_score  final_score
# 257      0.181506       0.8481     5.148031
# 698      0.161819       0.8658     5.138096
# 252      0.168945       0.8481     5.085225
# 367      0.159360       0.8481     5.037298
# 1676     0.423164       0.5719     4.975318

# %%
# --- Select top 15 segments ---
top_segments = df.sort_values("final_score", ascending=False).head(15).copy()

# --- Include previous and next segments ---
expanded_indices = set()
for idx in top_segments.index:
    if idx - 1 in df.index: expanded_indices.add(idx - 1)
    expanded_indices.add(idx)
    if idx + 1 in df.index: expanded_indices.add(idx + 1)

expanded_segments = df.loc[sorted(expanded_indices)].drop_duplicates(subset=["start","end"]).sort_values("start").reset_index(drop=True)

# --- Save results ---
expanded_segments.to_csv("highlight_segments_with_context.csv", index=False)
expanded_segments
# Out:
#       start      end                                               text  \
# 0    316.76   320.44   left-hand side, Byron should make the challen...
# 1    320.44   324.76   Byron does make the challenge, and wins a fre...
# 2    324.76   329.48   applause for the former West Ham player, and ...
# 3    520.28   524.20   the end of that one, but Norwich I don't thin...
# 4    524.20   530.44   tackle. Yeah well Steeperman went in hard on ...
# 5    530.44   534.84   kick to Manchester City, but after the decisi...
# 6    974.44   978.28   deflections, and eventually falls kindly for ...
# 7    978.28   983.16   the play out towards the right hand side, and...
# 8    983.16   987.80   that ball in play going back towards his own ...
# 9   1078.04  1083.00   side but driving at them like they just did t...
# 10  1083.00  1091.32   side delivers, McLean's head on, and he's in,...
# 11  1091.32  1097.32   rising at the near post to head the corner fi...
# 12  1103.00  1106.92   Moch as the City and it's a Kenny McLean head...
# 13  1109.88  1116.28   What a goal, great delivery from the corner, ...
# 14  1117.88  1121.80   now that's what you can see, now that's what ...
# 15  1131.72  1137.00   space and you take the game on, you drive for...
# 16  1137.00  1142.84   and they get them in that box from that corne...
# 17  1143.48  1147.88   Well he's already the mayor of Norwich, if th...
# 18  1704.04  1711.00   after unselfish play from Timo Pukki and nobo...
# 19  1711.80  1717.00   that's brilliant from Norwich City, what a gr...
# 20  1717.00  1721.08   but when it did come away to Pukki I thought ...
# 21  1942.20  1946.36   No one predicted it on the on the riverside w...
# 22  1946.36  1950.28   But you've got to have faith in your team and...
# 23  1950.28  1954.28   a hold out for 90 minutes but what I'm trying...
# 24  2813.72  2818.60   it's headed down should be away by Pukki and ...
# 25  2818.60  2823.00   Carrow Road the champions of the championship...
# 26  2823.00  2828.44   two goals to one yellows yellows Chantler-Mor...
# 27  3181.56  3186.36   there Steeperman picked it up really really q...
# 28  3186.36  3192.04   in the penalty area plays it to Pukian this i...
# 29  3192.60  3200.20   the back from Manchester City Otamendi was ro...
# 30  3200.20  3205.24   Timo Pukian and the Premier League's player o...
# 31  3205.24  3209.32   and Norwich City well this is getting better ...
# 32  3209.32  3214.68   it's Norwich City three Manchester City one. ...
# 33  3307.64  3311.96   mistakes like that I was just going to say ho...
# 34  3311.96  3319.00   how good are these set-up backs keep raving a...
# 35  3319.00  3324.20   schoolboy error and Pep Guardiola looked shoc...
# 36  4562.16  4566.16   18 minutes to go, Norwich City 3, Manchester ...
# 37  4566.16  4570.16       Outstanding, Byron and Amadou, outstanding\n
# 38  4570.16  4572.16   Normally defensive duties I keep talking about\n
# 39  5883.16  5885.16                            Norwich have done it!\n
# 40  5885.16  5887.16            That is a wonderful Carrow Road night\n
# 41  5887.16  5889.16                              A night to remember\n
# 42  5889.16  5891.16   It is one of the best results in Norwich City...
# 43  5891.16  5893.16       It's probably one of the biggest surprises\n
#
#     audio_score  vader_score  final_score
# 0      0.065584       0.0772     0.713921
# 1      0.090020       0.8555     4.727599
# 2      0.057842      -0.3612    -1.516789
# 3      0.109971      -0.6956    -2.928146
# 4      0.054855       0.9001     4.774777
# 5      0.048958       0.3919     2.204291
# 6      0.042176       0.4939     2.680378
# 7      0.067790       0.8777     4.727451
# 8      0.058793       0.6486     3.536967
# 9      0.099751       0.7096     4.046755
# 10     0.418614       0.5267     4.726571
# 11     0.346541      -0.3400     0.032707
# 12     0.221333       0.0000     1.106667
# 13     0.168945       0.8481     5.085225
# 14     0.160502       0.0000     0.802508
# 15     0.131571      -0.2500    -0.592146
# 16     0.181506       0.8481     5.148031
# 17     0.101396       0.6249     3.631481
# 18     0.206924       0.3400     2.734619
# 19     0.159360       0.8481     5.037298
# 20     0.148548      -0.4767    -1.640758
# 21     0.057939       0.0258     0.418696
# 22     0.067007       0.8947     4.808534
# 23     0.061501       0.0000     0.307505
# 24     0.057427       0.0000     0.287135
# 25     0.107766       0.8658     4.867829
# 26     0.145270       0.5106     3.279351
# 27     0.120082      -0.4939    -1.869092
# 28     0.342157       0.6369     4.895287
# 29     0.334303       0.3400     3.371516
# 30     0.233457       0.0000     1.167284
# 31     0.187507       0.7845     4.860033
# 32     0.168126      -0.3818    -1.068368
# 33     0.097438       0.0000     0.487188
# 34     0.161819       0.8658     5.138096
# 35     0.157857      -0.6124    -2.272715
# 36     0.260013       0.0000     1.300064
# 37     0.138437       0.8402     4.893186
# 38     0.060031       0.0258     0.429156
# 39     0.496202       0.0000     2.481009
# 40     0.423164       0.5719     4.975318
# 41     0.377630       0.0000     1.888151
# 42     0.329061       0.6369     4.829804
# 43     0.270936       0.2263     2.486178

# %%
from moviepy import VideoFileClip, concatenate_videoclips

buffer_sec = 2  # seconds to add before and after each segment

# Step 1: Merge overlapping segments with buffer
merged_segments = []
for idx, row in expanded_segments.iterrows():
    start = max(0, row["start"] - buffer_sec)  # don't go below 0
    end = row["end"] + buffer_sec
    if not merged_segments:
        merged_segments.append({"start": start, "end": end})
    else:
        last = merged_segments[-1]
        if start <= last["end"]:  # overlap or consecutive
            last["end"] = max(last["end"], end)
        else:
            merged_segments.append({"start": start, "end": end})

# Step 2: Load original video
video = VideoFileClip("NOR.mp4")

# Step 3: Extract clips
clips = []
for seg in merged_segments:
    start = seg["start"]
    end = seg["end"]
    if end - start > 0.5:  # skip very short segments
        clips.append(video.subclip(start, end))

# Step 4: Concatenate clips
highlight_reel = concatenate_videoclips(clips)

# Step 5: Export final video
highlight_reel.write_videofile("highlight_reel_with_buffer.mp4", codec="libx264", audio_codec="aac")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 28
#      26     end = seg["end"]
#      27     if end - start > 0.5:  # skip very short segments
# ---> 28         clips.append(video.subclip(start, end))
#      30 # Step 4: Concatenate clips
#      31 highlight_reel = concatenate_videoclips(clips)
#
# AttributeError: 'VideoFileClip' object has no attribute 'subclip'
